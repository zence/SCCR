# %%
require(readr)
# Out:
# Loading required package: readr

# %%
clin.data <- as.data.frame(read_tsv("../data/GSE62944_06_01_15_TCGA_24_548_Clinical_Variables_9264_Samples.txt"))

row.names(clin.data) <- clin.data$X1
clin.data$X1 <- NULL
clin.data$X2 <- NULL
clin.data$X3 <- NULL
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1], 'X2' [2], 'X3' [3]”Parsed with column specification:
# cols(
#   .default = col_character()
# )
# See spec(...) for full column specifications.

# %%
clin.data <- as.data.frame(t(clin.data))

# %%
options(repr.matrix.max.cols=600)
clin.data[which(row.names(clin.data) == "TCGA-AC-A3W6-01A-12R-A22K-07"), ]
# Out:
#                              bcr_patient_uuid
# TCGA-AC-A3W6-01A-12R-A22K-07 1B4CFAD1-E353-4411-97B6-2B7B9309E95E
#                              bcr_patient_barcode form_completion_date
# TCGA-AC-A3W6-01A-12R-A22K-07 TCGA-AC-A3W6        2012-9-24
#                              prospective_collection retrospective_collection
# TCGA-AC-A3W6-01A-12R-A22K-07 YES                    NO
#                              gender race  ethnicity
# TCGA-AC-A3W6-01A-12R-A22K-07 FEMALE WHITE NOT HISPANIC OR LATINO
#                              history_other_malignancy
# TCGA-AC-A3W6-01A-12R-A22K-07 Yes
#                              history_neoadjuvant_treatment tumor_status
# TCGA-AC-A3W6-01A-12R-A22K-07 No                            TUMOR FREE
#                              vital_status radiation_treatment_adjuvant
# TCGA-AC-A3W6-01A-12R-A22K-07 Alive        [Unknown]
#                              pharmaceutical_tx_adjuvant
# TCGA-AC-A3W6-01A-12R-A22K-07 [Unknown]
# ...
